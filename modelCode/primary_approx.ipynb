# %%
import pandas as pd
import geopandas as gpd

# %%
electorate_shapes = gpd.read_file("raw/CED_2024_AUST_GDA2020/CED_2024_AUST_GDA2020.shp")[["CED_CODE24", "CED_NAME24", "geometry"]].rename({"CED_NAME24":"2025Division","CED_CODE24":"2025DivisionCode"},axis=1)
polling_places = pd.read_csv("raw/GeneralPollingPlacesDownload-27966.csv",header=1,index_col="PollingPlaceID")[["PollingPlaceNm","Latitude", "Longitude","DivisionNm"]].rename({"DivisionNm":"2022Division"},axis=1)

# %%
gdf_points = gpd.GeoDataFrame(polling_places[["PollingPlaceNm","2022Division"]], geometry=gpd.points_from_xy(polling_places.Longitude, polling_places.Latitude), crs="EPSG:7844")

# %%
gdf_joined = gpd.sjoin(gdf_points, electorate_shapes, how="left", predicate="within")

# %%
PPMAPPER = gdf_joined.dropna()['2025Division']

# %%
NSW_votes2022 = pd.read_csv('raw/primaries/HouseStateFirstPrefsByPollingPlaceDownload-27966-NSW.csv',header=1)
NSW_votes2022allVoteTypes = pd.read_csv("raw/primaries/HouseFirstPrefsByCandidateByVoteTypeDownload-27966.csv",header=1)
NSW_votes2022allVoteTypes = NSW_votes2022allVoteTypes[NSW_votes2022allVoteTypes["StateAb"]=="NSW"][["DivisionNm", "PartyAb", "Surname", "GivenNm","OrdinaryVotes", "AbsentVotes", "ProvisionalVotes", "PrePollVotes", "PostalVotes", "TotalVotes"]]

# %%
def handle_row(row):
    if row['PollingPlaceID'] in PPMAPPER.index:
        newDIV = PPMAPPER.loc[row['PollingPlaceID']]
    else:newDIV = row['DivisionNm']

    if pd.isna(row['PartyAb']) and row['Surname']=="Informal":
        partyab = "INF"
    elif pd.isna(row['PartyAb']):
        partyab = "IND"
    else:
        partyab = row['PartyAb']

    og_numPPIDs = len(NSW_votes2022[NSW_votes2022["DivisionNm"]==row['DivisionNm']]["PollingPlaceID"].unique())
    candidate_idx = NSW_votes2022allVoteTypes[(NSW_votes2022allVoteTypes[["DivisionNm","Surname", "GivenNm"]] == [row['DivisionNm'],row['Surname'], row['GivenNm']]).all(axis=1)].index
    if len(candidate_idx)==1:
        candidate_idx=candidate_idx[0]
    else:
        print([row['DivisionNm'],row['Surname'], row['GivenNm'],row['PartyAb']])
        print(candidate_idx)
        raise Exception("Error multiple candidates detected. Should only be one.")

    candidate_absentee = NSW_votes2022allVoteTypes.loc[candidate_idx]["AbsentVotes"]
    candidate_provisional = NSW_votes2022allVoteTypes.loc[candidate_idx]["ProvisionalVotes"]
    candidate_prepoll = NSW_votes2022allVoteTypes.loc[candidate_idx]["PrePollVotes"]
    candidate_postal = NSW_votes2022allVoteTypes.loc[candidate_idx]["PostalVotes"]



    return pd.Series(
        {"PollingPlaceID":row['PollingPlaceID'],
         "DivisionNm":newDIV,
         "PartyAb":partyab,
         "Surname":row['Surname'],
         "GivenNm":row["GivenNm"],
         "OrdinaryVotes":row["OrdinaryVotes"],
         "AbsentVotes":candidate_absentee/og_numPPIDs,
         "ProvisionalVotes":candidate_provisional/og_numPPIDs, 
         "PrePollVotes":candidate_prepoll/og_numPPIDs,
         "PostalVotes": candidate_postal/og_numPPIDs,
         "TotalVotes": row["OrdinaryVotes"] + (candidate_absentee + candidate_provisional + candidate_prepoll + candidate_postal)/og_numPPIDs
         }
    )
        
NSW_votes2025 = NSW_votes2022.apply(handle_row,axis=1)

# %%
votes = NSW_votes2025.pivot_table(values="TotalVotes", index="DivisionNm", columns="PartyAb", aggfunc="sum")

# %%
votes.drop("INF",axis=1)
# Out:
# PartyAb                  AJP           ALP          ASP         AUD  \
# DivisionNm
# Banks                    NaN  27064.957701          NaN         NaN
# Barton                   NaN  47219.574596          NaN         NaN
# Bean                     NaN    308.103448          NaN    2.896552
# Bennelong         103.027721  35886.327781          NaN         NaN
# Berowra            41.827586  30654.617344          NaN         NaN
# Blaxland          391.103448  37071.050231          NaN         NaN
# Bradfield           7.372549  18326.038878          NaN         NaN
# Calare                   NaN  15979.655172          NaN         NaN
# Canberra          213.806228  16099.358003   127.922042   13.793103
# Chifley                  NaN  43752.835006          NaN         NaN
# Cook                     NaN  23968.078431          NaN         NaN
# Cowper                   NaN  16368.712318          NaN         NaN
# Cunningham               NaN  44261.233672          NaN         NaN
# Dobell            242.786429  42771.636429          NaN         NaN
# Eden-Monaro              NaN  38352.418702   791.611111  481.793103
# Farrer                   NaN  18242.000000  5130.459770         NaN
# Fenner                   NaN    164.551724          NaN    1.448276
# Fowler                   NaN  28022.480858          NaN         NaN
# Gilmore                  NaN  39378.781250          NaN         NaN
# Grayndler         857.901639  63070.258180          NaN         NaN
# Greenway           40.599516  37641.276336          NaN         NaN
# Hughes                   NaN  30583.511600          NaN         NaN
# Hume                     NaN  22613.633333  1603.000000         NaN
# Hunter           2102.953974  42496.774396          NaN         NaN
# Kingsford Smith          NaN  41753.417569          NaN         NaN
# Lindsay            28.771930  31850.284847    28.055556         NaN
# Lyne                     NaN  20911.483146          NaN         NaN
# Macarthur                NaN  36135.760101    45.111111         NaN
# Mackellar         203.352941   8194.039216          NaN         NaN
# Macquarie        1954.912281  43211.161205          NaN         NaN
# Mallee                   NaN    185.000000    50.885057         NaN
# McMahon            45.655172  56035.174745          NaN         NaN
# Mitchell           95.482759  25693.065231          NaN         NaN
# New England       180.676056  21468.341976          NaN         NaN
# Newcastle        2602.477887  46558.944571          NaN         NaN
# Nicholls                 NaN    494.000000   108.885057         NaN
# North Sydney             NaN     89.490909          NaN         NaN
# Page                     NaN  18257.813748          NaN         NaN
# Parkes                   NaN  20664.133186  2256.448980         NaN
# Parramatta       1606.655172  32501.973613          NaN         NaN
# Paterson           38.070423  41378.473018          NaN         NaN
# Reid                     NaN  34772.824474          NaN         NaN
# Richmond                 NaN  29138.216702          NaN         NaN
# Riverina                 NaN  26494.675366  4290.121315  151.068966
# Robertson        1876.320000  38523.620000          NaN         NaN
# Shortland        2772.148216  38766.307209          NaN         NaN
# Sydney            383.058857  64663.074490          NaN         NaN
# Warringah        1190.039216  11813.284492          NaN         NaN
# Watson                   NaN  48064.505237          NaN         NaN
# Wentworth                NaN  23010.455343          NaN         NaN
# Werriwa                  NaN  25175.248109          NaN         NaN
# Whitlam                  NaN  46581.366110   294.500000         NaN
#
# PartyAb                  CEC          CYA        DPDA           GRN  \
# DivisionNm
# Banks                    NaN          NaN         NaN   6835.387785
# Barton                   NaN          NaN         NaN  10611.260022
# Bean                     NaN          NaN         NaN     81.333333
# Bennelong                NaN          NaN  790.942308  11459.995660
# Berowra                  NaN   466.272727  258.807692  17867.142273
# Blaxland                 NaN          NaN         NaN   4871.444022
# Bradfield                NaN          NaN         NaN   8720.105507
# Calare                   NaN          NaN         NaN   4819.551724
# Canberra           23.078357    29.198299   13.269231   5512.255846
# Chifley                  NaN          NaN         NaN   4625.958250
# Cook                     NaN          NaN         NaN   9326.352941
# Cowper                   NaN    13.034884         NaN   6849.331559
# Cunningham       1030.307692          NaN         NaN  22390.698113
# Dobell              4.800000     5.160000         NaN   8269.520000
# Eden-Monaro              NaN          NaN         NaN   8450.586806
# Farrer                   NaN          NaN         NaN   8830.850575
# Fenner                   NaN          NaN         NaN     61.666667
# Fowler                   NaN          NaN         NaN   3913.042525
# Gilmore                  NaN          NaN         NaN  11187.156250
# Grayndler          47.830508          NaN         NaN  24278.100654
# Greenway                 NaN          NaN         NaN   6284.332089
# Hughes              9.173077          NaN         NaN   6711.665062
# Hume                     NaN          NaN         NaN   5093.066667
# Hunter                   NaN          NaN         NaN   9232.590578
# Kingsford Smith    28.966102          NaN         NaN  13094.353493
# Lindsay                  NaN          NaN         NaN   7689.002578
# Lyne                     NaN          NaN         NaN   7727.224719
# Macarthur                NaN          NaN         NaN   6223.704040
# Mackellar                NaN          NaN         NaN   6313.453431
# Macquarie                NaN          NaN         NaN   9774.833168
# Mallee                   NaN          NaN         NaN     71.287356
# McMahon                  NaN          NaN         NaN   6958.067633
# Mitchell                 NaN    22.090909         NaN  11816.086307
# New England              NaN          NaN         NaN   8068.582987
# Newcastle                NaN  1037.865385         NaN  20857.884802
# Nicholls                 NaN          NaN         NaN    158.287356
# North Sydney             NaN          NaN         NaN     42.145455
# Page                     NaN   783.860465         NaN   8309.477008
# Parkes                   NaN          NaN         NaN   5009.588046
# Parramatta               NaN    11.272727  112.807692   7496.054457
# Paterson                 NaN          NaN         NaN   8119.279464
# Reid                     NaN          NaN         NaN   7774.440075
# Richmond                 NaN    15.034884         NaN  25287.036998
# Riverina                 NaN          NaN         NaN   7159.237528
# Robertson         263.400000   212.680000         NaN  10235.460000
# Shortland                NaN    45.711538         NaN  10124.303900
# Sydney            820.542373     4.818182   32.173077  28193.905423
# Warringah                NaN          NaN         NaN   8267.568226
# Watson                   NaN          NaN         NaN   5958.828852
# Wentworth          92.728814          NaN         NaN  13166.646718
# Werriwa                  NaN          NaN         NaN   4388.190544
# Whitlam            51.173077          NaN         NaN  11500.674528
#
# PartyAb                  IAP          IMO  ...          LDP            LP  \
# DivisionNm                                 ...
# Banks                    NaN          NaN  ...   975.192308  35993.888811
# Barton                   NaN          NaN  ...   228.192308  32163.393268
# Bean                     NaN     7.310345  ...    26.620690    198.344828
# Bennelong                NaN   183.381818  ...  1538.638667  45340.500430
# Berowra                  NaN          NaN  ...  2410.297815  57316.833686
# Blaxland                 NaN          NaN  ...   735.497731  19120.080734
# Bradfield                NaN   165.018182  ...   358.490909  46166.998593
# Calare                   NaN          NaN  ...          NaN           NaN
# Canberra           82.553531   127.674622  ...   999.316497  14024.803065
# Chifley                  NaN    33.000000  ...  2637.685267  20415.203533
# Cook                     NaN          NaN  ...          NaN  54377.745098
# Cowper             41.697674          NaN  ...  4588.098783           NaN
# Cunningham               NaN          NaN  ...  2488.721335  25945.753266
# Dobell             27.840000    19.680000  ...  1570.761429  33931.827381
# Eden-Monaro              NaN   698.620690  ...  1972.661518  34662.014308
# Farrer                   NaN          NaN  ...  1527.528736  49738.356322
# Fenner                   NaN     5.655172  ...    13.310345    129.172414
# Fowler                   NaN          NaN  ...  2472.615603  14594.024475
# Gilmore                  NaN          NaN  ...   877.031250  46061.859375
# Grayndler                NaN          NaN  ...   192.461538  23754.760955
# Greenway                 NaN     5.192982  ...  2556.964849  28006.151991
# Hughes                   NaN          NaN  ...  1417.249883  40090.981441
# Hume                     NaN          NaN  ...  1147.366667  38202.200000
# Hunter                   NaN  1480.400194  ...   292.934729   4232.691502
# Kingsford Smith          NaN          NaN  ...          NaN  26052.713983
# Lindsay                  NaN  1792.192982  ...  1583.096207  45061.431576
# Lyne                     NaN          NaN  ...  5936.258427           NaN
# Macarthur                NaN          NaN  ...  1743.102525  22337.705051
# Mackellar                NaN          NaN  ...          NaN  41033.012255
# Macquarie                NaN  1530.228070  ...  1403.257862  37441.006289
# Mallee                   NaN          NaN  ...    22.367816    653.160920
# McMahon                  NaN          NaN  ...  3973.260950  30369.817800
# Mitchell                 NaN          NaN  ...  3240.197126  52647.848882
# New England        41.477273   115.036012  ...  3228.668561           NaN
# Newcastle                NaN  1115.171685  ...   113.915025  25726.625947
# Nicholls                 NaN          NaN  ...    32.367816   1719.160920
# North Sydney             NaN     2.072727  ...     8.963636    193.545455
# Page             1632.209302     6.242424  ...  3634.786616           NaN
# Parkes           4376.204545  1482.897727  ...  6690.925557           NaN
# Parramatta               NaN          NaN  ...  1420.071032  28920.611563
# Paterson                 NaN  1657.171928  ...  2001.874467  37564.568966
# Reid                     NaN          NaN  ...  1466.384615  31715.704758
# Richmond           41.697674  2249.272727  ...  7690.181818           NaN
# Riverina                 NaN   184.793103  ...  6109.799075  10096.381226
# Robertson        1082.320000  1083.640000  ...   853.120000  40437.500000
# Shortland                NaN    92.964789  ...  2655.821429  29343.256868
# Sydney                   NaN    16.363636  ...   627.774686  34897.341265
# Warringah                NaN   117.018182  ...   271.490909  36553.452540
# Watson                   NaN          NaN  ...    14.576923  23249.728008
# Wentworth                NaN          NaN  ...  1269.716981  41616.401891
# Werriwa                  NaN          NaN  ...  6063.441135  20901.711584
# Whitlam                  NaN          NaN  ...  3814.939949  33133.726778
#
# PartyAb                NAFD            NP            ON          SAL  \
# DivisionNm
# Banks            732.673077           NaN   2663.503437          NaN
# Barton           181.173077           NaN   4655.633510          NaN
# Bean                    NaN           NaN     37.206897          NaN
# Bennelong               NaN           NaN   1759.286671          NaN
# Berowra                 NaN           NaN   3337.278425          NaN
# Blaxland                NaN           NaN   3145.147056          NaN
# Bradfield               NaN           NaN   1509.483329          NaN
# Calare                  NaN  50407.448276   8934.620690          NaN
# Canberra          10.038462   2274.983188   2094.381452    23.762712
# Chifley                 NaN           NaN   5099.787234          NaN
# Cook                    NaN           NaN   4328.098039          NaN
# Cowper                  NaN  45793.979847   9328.806975          NaN
# Cunningham              NaN           NaN   5735.809869          NaN
# Dobell                  NaN           NaN   7616.747381          NaN
# Eden-Monaro             NaN           NaN   4420.943307          NaN
# Farrer                  NaN           NaN   6118.666667          NaN
# Fenner                  NaN           NaN     15.103448          NaN
# Fowler                  NaN           NaN   2884.470074          NaN
# Gilmore                 NaN           NaN   4378.078125          NaN
# Grayndler               NaN           NaN   2776.543498   104.406780
# Greenway                NaN           NaN   2366.439808          NaN
# Hughes                  NaN           NaN   3831.943206          NaN
# Hume                    NaN           NaN   7212.400000          NaN
# Hunter                  NaN  25228.338028  10727.221128          NaN
# Kingsford Smith         NaN           NaN   3155.150121    22.881356
# Lindsay                 NaN           NaN   5915.456389          NaN
# Lyne                    NaN  43129.269663   7837.730337          NaN
# Macarthur               NaN           NaN   6232.316162          NaN
# Mackellar               NaN           NaN   2664.400735          NaN
# Macquarie               NaN           NaN   5390.824561          NaN
# Mallee                  NaN           NaN     65.333333          NaN
# McMahon                 NaN           NaN   5358.027932          NaN
# Mitchell                NaN           NaN   2975.631195          NaN
# New England             NaN  54694.879748   5660.131909          NaN
# Newcastle               NaN    348.732394   4957.096415          NaN
# Nicholls                NaN           NaN    128.333333          NaN
# North Sydney            NaN           NaN      5.981818          NaN
# Page                    NaN  44623.243746   5295.437250          NaN
# Parkes                  NaN  52034.031852   8204.519758          NaN
# Parramatta              NaN           NaN   1997.198846          NaN
# Paterson                NaN   2435.896503   8252.546431          NaN
# Reid                    NaN           NaN   1806.032534          NaN
# Richmond                NaN  24943.178647   4195.456660          NaN
# Riverina                NaN  36716.285714   7854.363203          NaN
# Robertson               NaN           NaN   4057.160000          NaN
# Shortland               NaN    558.732394   5953.790996          NaN
# Sydney            24.096154           NaN   2944.365609  1221.898305
# Warringah               NaN           NaN   2017.901092          NaN
# Watson            13.019231           NaN   4674.256618          NaN
# Wentworth               NaN           NaN   1510.750834   145.050847
# Werriwa                 NaN           NaN   3339.964775          NaN
# Whitlam                 NaN           NaN   7537.240929          NaN
#
# PartyAb                 SOPA          SPP         TNL         UAPP
# DivisionNm
# Banks                    NaN          NaN         NaN  4590.067368
# Barton                   NaN          NaN         NaN  6447.468408
# Bean                     NaN    17.827586         NaN    15.942529
# Bennelong        1431.961538   411.672727  304.110985  3051.993147
# Berowra          1593.447552          NaN         NaN  3149.026082
# Blaxland           56.692308          NaN         NaN  5104.506922
# Bradfield                NaN   389.127273  322.018182  2356.408387
# Calare                   NaN          NaN         NaN  3983.793103
# Canberra          115.785437    69.673354   23.975881  1635.880352
# Chifley                  NaN          NaN         NaN  4380.170614
# Cook                     NaN          NaN         NaN  4724.156863
# Cowper                   NaN          NaN    6.686047  2759.924451
# Cunningham               NaN          NaN         NaN  5399.650218
# Dobell           1946.666667          NaN         NaN  3749.212381
# Eden-Monaro              NaN  1716.655172         NaN  2693.650682
# Farrer                   NaN          NaN         NaN  3105.022989
# Fenner                   NaN    10.413793         NaN    10.471264
# Fowler                   NaN          NaN         NaN  5787.219872
# Gilmore                  NaN          NaN         NaN  3048.453125
# Grayndler        1121.447667          NaN         NaN  3414.384472
# Greenway                 NaN          NaN         NaN  3419.259734
# Hughes                   NaN          NaN         NaN  7228.570712
# Hume                     NaN          NaN         NaN  5104.266667
# Hunter                   NaN          NaN         NaN  4215.806668
# Kingsford Smith          NaN          NaN         NaN  3513.116152
# Lindsay                  NaN          NaN         NaN  4097.548524
# Lyne                     NaN          NaN         NaN  4118.044944
# Macarthur                NaN          NaN         NaN  4559.175758
# Mackellar                NaN          NaN  494.895833  2919.860294
# Macquarie                NaN          NaN         NaN  3042.232373
# Mallee                   NaN          NaN         NaN    56.494253
# McMahon                  NaN          NaN         NaN  8443.675373
# Mitchell           75.436364          NaN         NaN  3559.849940
# New England              NaN          NaN         NaN  3111.529663
# Newcastle                NaN          NaN         NaN  2612.064188
# Nicholls                 NaN          NaN         NaN    84.494253
# North Sydney             NaN     9.509091    6.072727     6.909091
# Page                     NaN          NaN  228.255814  2338.423450
# Parkes                   NaN          NaN         NaN  2792.919383
# Parramatta        284.647552          NaN         NaN  3838.654712
# Paterson                 NaN          NaN         NaN  4011.238700
# Reid             1227.769231          NaN         NaN  2273.694311
# Richmond                 NaN          NaN    5.686047  2958.383721
# Riverina                 NaN   465.448276         NaN  2928.236160
# Robertson         229.500000          NaN         NaN  2991.980000
# Shortland                NaN          NaN         NaN  2978.496169
# Sydney            436.645684    59.545455   46.551136  3632.791790
# Warringah                NaN   273.127273  265.747348  2362.489528
# Watson                   NaN          NaN         NaN  6351.609159
# Wentworth                NaN          NaN         NaN  2433.740692
# Werriwa                  NaN          NaN         NaN  6104.358629
# Whitlam                  NaN          NaN         NaN  5676.681785
#
# [52 rows x 21 columns]

# %%
votes.sum().sum()
# Out:
# 4959584.0

# %%
NSW_votes2022allVoteTypes["TotalVotes"].sum()
# Out:
# 4959584
