# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.rand(1000,2)

# %%
plt.rcParams.update({'font.size': 16})

fig,ax = plt.subplots(figsize=(10,10))

ax.scatter(x[:,0],x[:,1], c='k', alpha=0.8, s=20)
ax.set_xlim([0,1])
ax.set_ylim([0,1])
# Out:
# (0.0, 1.0)
